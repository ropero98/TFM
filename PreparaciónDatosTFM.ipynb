# %% [markdown]
# <a href="https://colab.research.google.com/github/ropero98/TFM/blob/main/Preparaci%C3%B3nDatosTFM.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Vamos a comenzar realizando una revisión y limpieza del data set si fuera necesario
#Empezamos por importar las librerias que usaremos para este analisis previo
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/heart_2020_cleaned.csv')

# %%
#Vemos una muestra de las 10 primeras filas de nuestro dataset
df.head(10)
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No             3.0
# 1           No  20.34      No              No    Yes             0.0
# 2           No  26.58     Yes              No     No            20.0
# 3           No  24.21      No              No     No             0.0
# 4           No  23.71      No              No     No            28.0
# 5          Yes  28.87     Yes              No     No             6.0
# 6           No  21.63      No              No     No            15.0
# 7           No  31.64     Yes              No     No             5.0
# 8           No  26.45      No              No     No             0.0
# 9           No  40.69      No              No     No             0.0
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race  \
# 0          30.0          No  Female        55-59  White
# 1           0.0          No  Female  80 or older  White
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 319795 entries, 0 to 319794
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   HeartDisease      319795 non-null  object
#  1   BMI               319795 non-null  float64
#  2   Smoking           319795 non-null  object
#  3   AlcoholDrinking   319795 non-null  object
#  4   Stroke            319795 non-null  object
#  5   PhysicalHealth    319795 non-null  float64
#  6   MentalHealth      319795 non-null  float64
#  7   DiffWalking       319795 non-null  object
#  8   Sex               319795 non-null  object
#  9   AgeCategory       319795 non-null  object
#  10  Race              319795 non-null  object
#  11  Diabetic          319795 non-null  object
#  12  PhysicalActivity  319795 non-null  object
#  13  GenHealth         319795 non-null  object
#  14  SleepTime         319795 non-null  float64
# ...

# %%
df.describe()
# Out:
#                  BMI  PhysicalHealth   MentalHealth      SleepTime
# count  319795.000000    319795.00000  319795.000000  319795.000000
# mean       28.325399         3.37171       3.898366       7.097075
# std         6.356100         7.95085       7.955235       1.436007
# min        12.020000         0.00000       0.000000       1.000000
# 25%        24.030000         0.00000       0.000000       6.000000
# 50%        27.340000         0.00000       0.000000       7.000000
# 75%        31.420000         2.00000       3.000000       8.000000
# max        94.850000        30.00000      30.000000      24.000000

# %%
df.isnull().sum()
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
df['GenHealth'].unique()
# Out:
# array(['Very good', 'Fair', 'Good', 'Poor', 'Excellent'], dtype=object)

# %%
for i in range(len(df)):
  if (df['Smoking'][i]=='Yes'):
    df['Smoking'][i]=1
  else:
    df['Smoking'][i]=0
  if (df['AlcoholDrinking'][i]=='Yes'):
    df['AlcoholDrinking'][i]=1
  else:
    df['AlcoholDrinking'][i]=0
  if (df['Stroke'][i]=='Yes'):
    df['Stroke'][i]=1
  else:
    df['Stroke'][i]=0
  if (df['DiffWalking'][i]=='Yes'):
    df['DiffWalking'][i]=1
  else:
    df['DiffWalking'][i]=0
  if (df['Sex'][i]=='Female'):
    df['Sex'][i]=1
  else:
    df['Sex'][i]=0
  if (df['AgeCategory'][i]=='18-24'):
    df['AgeCategory'][i]=0
  elif (df['AgeCategory'][i]=='25-29'):
    df['AgeCategory'][i]=1
  elif (df['AgeCategory'][i]=='30-34'):
    df['AgeCategory'][i]=2
  elif (df['AgeCategory'][i]=='35-39'):
    df['AgeCategory'][i]=3
  elif (df['AgeCategory'][i]=='40-44'):
    df['AgeCategory'][i]=4
  elif (df['AgeCategory'][i]=='45-49'):
    df['AgeCategory'][i]=5
  elif (df['AgeCategory'][i]=='50-54'):
    df['AgeCategory'][i]=6
  elif (df['AgeCategory'][i]=='55-59'):
    df['AgeCategory'][i]=7
  elif (df['AgeCategory'][i]=='60-64'):
    df['AgeCategory'][i]=8
  elif (df['AgeCategory'][i]=='65-69'):
    df['AgeCategory'][i]=9
  elif (df['AgeCategory'][i]=='70-74'):
    df['AgeCategory'][i]=10
  elif (df['AgeCategory'][i]=='75-79'):
    df['AgeCategory'][i]=11
  else:
    df['AgeCategory'][i]=12
  if (df['Race'][i]=='White'):
    df['Race'][i]=0
  elif (df['Race'][i]=='Black'):
    df['Race'][i]=1
  elif (df['Race'][i]=='Asian'):
    df['Race'][i]=2
  elif (df['Race'][i]=='American Indian/Alaskan Native'):
    df['Race'][i]=3
  elif (df['Race'][i]=='Hispanic'):
    df['Race'][i]=4
  else:
    df['Race'][i]=5
  if (df['Diabetic'][i]=='Yes'):
    df['Diabetic'][i]=0
  elif (df['Diabetic'][i]=='No'):
    df['Diabetic'][i]=1
  elif (df['Diabetic'][i]=='No, borderline diabetes'):
    df['Diabetic'][i]=2
  else:
    df['Diabetic'][i]=3
  if (df['PhysicalActivity'][i]=='Yes'):
    df['PhysicalActivity'][i]=1
  else:
    df['PhysicalActivity'][i]=0
  if (df['GenHealth'][i]=='Poor'):
    df['GenHealth'][i]=0
  elif (df['GenHealth'][i]=='Fair'):
    df['GenHealth'][i]=1
  elif (df['GenHealth'][i]=='Good'):
    df['GenHealth'][i]=2
  elif (df['GenHealth'][i]=='Very good'):
    df['GenHealth'][i]=3
  else:
    df['GenHealth'][i]=4
  if (df['Asthma'][i]=='Yes'):
    df['Asthma'][i]=1
  else:
    df['Asthma'][i]=0
  if (df['KidneyDisease'][i]=='Yes'):
    df['KidneyDisease'][i]=1
  else:
    df['KidneyDisease'][i]=0
  if (df['SkinCancer'][i]=='Yes'):
    df['SkinCancer'][i]=1
  else:
    df['SkinCancer'][i]=0

# %%
df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60       1               0      0             3.0
# 1           No  20.34       0               0      1             0.0
# 2           No  26.58       1               0      0            20.0
# 3           No  24.21       0               0      0             0.0
# 4           No  23.71       0               0      0            28.0
#
#    MentalHealth DiffWalking Sex AgeCategory Race Diabetic PhysicalActivity  \
# 0          30.0           0   1           7    0        0                1
# 1           0.0           0   1          12    0        1                1
# 2          30.0           0   0           9    0        0                1
# 3           0.0           0   1          11    0        1                0
# 4           0.0           1   1           4    0        1                1
#
#   GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
df.to_excel("output.xlsx")

# %%
sns.pairplot(df,hue='HeartDisease')
